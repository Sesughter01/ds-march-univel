# %%
1+1
# Out:
# 2

# %%
print("ade")
# Out:
# ade

# %%
import pymysql

# %%
raise(SyntaxError("Error on line... OOupsie i gatcha..!!"))
# Out:
# Traceback (most recent call last):
#
#   File "c:\users\inyang\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "C:\Users\INYANG\AppData\Local\Temp/ipykernel_26840/878848758.py", line 1, in <module>
#     raise(SyntaxError("Error on line... OOupsie i gatcha..!!"))
#
#   File "<string>", line unknown
# SyntaxError: Error on line... OOupsie i gatcha..!!

# %%
x = 30

# %%
y = 17

# %%
import pymysql.cursors

# Connect to the database
connection = pymysql.connect(host='localhost',
                             user='root',
                             password='',
                             database='exams',
                             cursorclass=pymysql.cursors.DictCursor)

with connection:
    with connection.cursor() as cursor:
        # Create a new record
        sql = "INSERT INTO `student` (name, age, class) VALUES ('{}', '{}', '{}')"
        cursor.execute(sql.format('Atha', 30, 300))

    # connection is not autocommit by default. So you must commit to save
    # your changes.
    connection.commit()

# %%
with connection.cursor() as cursor:
    # Read a single record
    sql = "SELECT `id`, `password` FROM `users` WHERE `email`=%s"
    cursor.execute(sql, ('webmaster@python.org',))
    result = cursor.fetchone()
    print(result)

# %%
import csv

with open('Loan-2022-02-27.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            print(f'\t{row[0]} works in the {row[1]} department, and was born in {row[2]}.')
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Column names are id, customerId, currency, loanAmount, elgible_amount, dateOfDisbursement, dateOfCollection, due_date, totalCollectionAmount, numberOfRepayments, mandateReference, loan_disk_id, loan_status, average_salary, loan_obligation, monthly_repayment, loan_comment, paid_amount, last_paid_amount, last_paid_date, outstanding_loan_bal, remita_loan_repayment_ref, eligible_id, repayment_id, mandate_close, repayment_count, loan_percentage_taken, eligible_for_top_up, topup_eligible_amount
# 	8907 works in the r_10398033 department, and was born in Naira.
# 	8906 works in the r_11371726 department, and was born in Naira.
# 	8905 works in the r_8698837678 department, and was born in Naira.
# 	8904 works in the r_10879657 department, and was born in Naira.
# 	8903 works in the r_10647961 department, and was born in Naira.
# 	8902 works in the r_2001577878 department, and was born in Naira.
# 	8901 works in the r_11004343 department, and was born in Naira.
# 	8900 works in the r_2002337974 department, and was born in Naira.
# 	8899 works in the r_11531057 department, and was born in Naira.
# 	8898 works in the r_2000025118 department, and was born in Naira.
# 	8897 works in the r_10852934 department, and was born in Naira.
# 	8896 works in the r_10133422 department, and was born in Naira.
# 	8895 works in the r_2001715481 department, and was born in Naira.
# 	8894 works in the r_10196356 department, and was born in Naira.
# 	8893 works in the r_2000709686 department, and was born in Naira.
# 	8892 works in the r_2001665579 department, and was born in Naira.
# 	8891 works in the r_2001955992 department, and was born in Naira.
# 	8890 works in the r_10964527 department, and was born in Naira.
# 	8889 works in the r_11006504 department, and was born in Naira.
# 	8888 works in the r_11644661 department, and was born in Naira.
# 	8887 works in the r_11349455 department, and was born in Naira.
# 	8886 works in the r_11225652 department, and was born in Naira.
# 	8885 works in the r_2001579887 department, and was born in Naira.
# 	8884 works in the r_11300402 department, and was born in Naira.
# 	8883 works in the r_10751669 department, and was born in Naira.
# 	8882 works in the r_2001892857 department, and was born in Naira.
# 	8881 works in the r_8698862608 department, and was born in Naira.
# 	8880 works in the r_2001585737 department, and was born in Naira.
# 	8879 works in the r_10732956 department, and was born in Naira.
# 	8878 works in the r_2001694050 department, and was born in Naira.
# 	8877 works in the r_8698835861 department, and was born in Naira.
# 	8876 works in the r_11358034 department, and was born in Naira.
# 	8875 works in the r_2001635697 department, and was born in Naira.
# 	8874 works in the r_10126950 department, and was born in Naira.
# 	8873 works in the r_11299101 department, and was born in Naira.
# 	8872 works in the r_10798866 department, and was born in Naira.
# 	8871 works in the r_10466553 department, and was born in Naira.
# 	8870 works in the r_11012608 department, and was born in Naira.
# 	8869 works in the r_10166707 department, and was born in Naira.
# 	8868 works in the r_2001624141 department, and was born in Naira.
# 	8867 works in the r_8698841291 department, and was born in Naira.
# 	8866 works in the r_2001365276 department, and was born in Naira.
# 	8865 works in the r_10439861 department, and was born in Naira.
# 	8864 works in the r_2001957149 department, and was born in Naira.
# 	8863 works in the r_11254733 department, and was born in Naira.
# 	8862 works in the r_11366799 department, and was born in Naira.
# 	8861 works in the r_2001545224 department, and was born in Naira.
# 	8860 works in the r_10046616 department, and was born in Naira.
# 	8859 works in the r_2000697228 department, and was born in Naira.
# 	8858 works in the r_8698816280 department, and was born in Naira.
# 	8857 works in the r_10122489 department, and was born in Naira.
# 	8856 works in the r_2001695840 department, and was born in Naira.
# 	8855 works in the r_8698809151 department, and was born in Naira.
# 	8854 works in the r_2001972373 department, and was born in Naira.
# 	8853 works in the r_2000098885 department, and was born in Naira.
# 	8852 works in the r_10857545 department, and was born in Naira.
# 	8851 works in the r_2000042584 department, and was born in Naira.
# 	8850 works in the r_2001953598 department, and was born in Naira.
# 	8849 works in the r_2001662290 department, and was born in Naira.
# 	8848 works in the r_8698816878 department, and was born in Naira.
# 	8847 works in the r_10492093 department, and was born in Naira.
# 	8846 works in the r_11589253 department, and was born in Naira.
# 	8845 works in the r_2001773460 department, and was born in Naira.
# 	8844 works in the r_2001692685 department, and was born in Naira.
# 	8843 works in the r_2001994522 department, and was born in Naira.
# 	8842 works in the r_2001764791 department, and was born in Naira.
# 	8841 works in the r_2002014342 department, and was born in Naira.
# 	8840 works in the r_8698817473 department, and was born in Naira.
# 	8839 works in the r_8698816280 department, and was born in Naira.
# 	8838 works in the r_11690714 department, and was born in Naira.
# 	8837 works in the r_2000110418 department, and was born in Naira.
# 	8836 works in the r_2001734225 department, and was born in Naira.
# 	8835 works in the r_8698852979 department, and was born in Naira.
# 	8834 works in the r_11335585 department, and was born in Naira.
# 	8833 works in the r_10179553 department, and was born in Naira.
# 	8832 works in the r_10466553 department, and was born in Naira.
# 	8831 works in the r_11171307 department, and was born in Naira.
# 	8830 works in the r_11160843 department, and was born in Naira.
# 	8829 works in the r_11136150 department, and was born in Naira.
# 	8828 works in the r_8698815689 department, and was born in Naira.
# 	8827 works in the r_2001556842 department, and was born in Naira.
# 	8826 works in the r_2001867072 department, and was born in Naira.
# 	8825 works in the r_11232118 department, and was born in Naira.
# 	8824 works in the r_8698811638 department, and was born in Naira.
# 	8823 works in the r_11144705 department, and was born in Naira.
# 	8822 works in the r_10033384 department, and was born in Naira.
# 	8821 works in the r_2001618965 department, and was born in Naira.
# 	8820 works in the r_2001959499 department, and was born in Naira.
# 	8819 works in the r_8698868869 department, and was born in Naira.
# 	8818 works in the r_2001568325 department, and was born in Naira.
# 	8817 works in the r_2002041706 department, and was born in Naira.
# 	8816 works in the r_11459108 department, and was born in Naira.
# 	8815 works in the r_11539000 department, and was born in Naira.
# 	8814 works in the r_2000856881 department, and was born in Naira.
# 	8813 works in the r_11114377 department, and was born in Naira.
# 	8812 works in the r_2001768050 department, and was born in Naira.
# 	8811 works in the r_2002034345 department, and was born in Naira.
# 	8810 works in the r_2001565498 department, and was born in Naira.
# 	8809 works in the r_2001827278 department, and was born in Naira.
# 	8808 works in the r_8698835588 department, and was born in Naira.
# 	8807 works in the r_8698805357 department, and was born in Naira.
# 	8806 works in the r_2001803071 department, and was born in Naira.
# 	8805 works in the r_2001584200 department, and was born in Naira.
# 	8804 works in the r_11114121 department, and was born in Naira.
# 	8803 works in the r_2001618242 department, and was born in Naira.
# 	8802 works in the r_10904814 department, and was born in Naira.
# 	8801 works in the r_2001564945 department, and was born in Naira.
# 	8800 works in the r_2001670188 department, and was born in Naira.
# 	8799 works in the r_2001567670 department, and was born in Naira.
# 	8798 works in the r_10301878 department, and was born in Naira.
# 	8797 works in the r_11310212 department, and was born in Naira.
# 	8796 works in the r_2001968779 department, and was born in Naira.
# 	8795 works in the r_2002183635 department, and was born in Naira.
# 	8794 works in the r_2001869932 department, and was born in Naira.
# 	8793 works in the r_2001986650 department, and was born in Naira.
# 	8792 works in the r_2001557525 department, and was born in Naira.
# 	8791 works in the r_11140787 department, and was born in Naira.
# 	8790 works in the r_2001613540 department, and was born in Naira.
# 	8789 works in the r_8698866829 department, and was born in Naira.
# 	8788 works in the r_11479263 department, and was born in Naira.
# 	8787 works in the r_11006054 department, and was born in Naira.
# 	8786 works in the r_2002195561 department, and was born in Naira.
# 	8785 works in the r_2001855515 department, and was born in Naira.
# 	8784 works in the r_2002187838 department, and was born in Naira.
# 	8783 works in the r_2001764805 department, and was born in Naira.
# 	8782 works in the r_2001638540 department, and was born in Naira.
# 	8781 works in the r_10515491 department, and was born in Naira.
# 	8780 works in the r_11179843 department, and was born in Naira.
# 	8779 works in the r_8698864138 department, and was born in Naira.
# 	8778 works in the r_2001655819 department, and was born in Naira.
# 	8777 works in the r_2001779355 department, and was born in Naira.
# 	8776 works in the r_10294286 department, and was born in Naira.
# 	8775 works in the r_2001871649 department, and was born in Naira.
# 	8774 works in the r_2001697944 department, and was born in Naira.
# 	8773 works in the r_2001794154 department, and was born in Naira.
# 	8772 works in the r_8698814040 department, and was born in Naira.
# 	8771 works in the r_2001997451 department, and was born in Naira.
# 	8770 works in the r_2001649114 department, and was born in Naira.
# 	8769 works in the r_2001673225 department, and was born in Naira.
# 	8768 works in the r_11634460 department, and was born in Naira.
# 	8767 works in the r_2002100901 department, and was born in Naira.
# 	8766 works in the r_8698849638 department, and was born in Naira.
# 	8765 works in the r_8698838703 department, and was born in Naira.
# 	8764 works in the r_11425533 department, and was born in Naira.
# 	8763 works in the r_11472625 department, and was born in Naira.
# 	8762 works in the r_11430807 department, and was born in Naira.
# 	8761 works in the r_2001878941 department, and was born in Naira.
# 	8760 works in the r_2001801719 department, and was born in Naira.
# 	8759 works in the r_10559681 department, and was born in Naira.
# 	8758 works in the r_11353730 department, and was born in Naira.
# 	8757 works in the r_2001722325 department, and was born in Naira.
# 	8756 works in the r_10938018 department, and was born in Naira.
# 	8755 works in the r_10135601 department, and was born in Naira.
# 	8754 works in the r_10147482 department, and was born in Naira.
# 	8753 works in the r_2002101962 department, and was born in Naira.
# 	8752 works in the r_8698869594 department, and was born in Naira.
# 	8751 works in the r_2001843692 department, and was born in Naira.
# 	8750 works in the r_10311629 department, and was born in Naira.
# 	8749 works in the r_11629947 department, and was born in Naira.
# 	8748 works in the r_2002056328 department, and was born in Naira.
# 	8747 works in the r_10599674 department, and was born in Naira.
# 	8746 works in the r_2001682677 department, and was born in Naira.
# 	8745 works in the r_10088546 department, and was born in Naira.
# 	8744 works in the r_2001634285 department, and was born in Naira.
# 	8743 works in the r_2002022162 department, and was born in Naira.
# 	8742 works in the r_2001830606 department, and was born in Naira.
# 	8741 works in the r_2001611664 department, and was born in Naira.
# 	8740 works in the r_10963365 department, and was born in Naira.
# 	8739 works in the r_2002022730 department, and was born in Naira.
# 	8738 works in the r_8698816796 department, and was born in Naira.
# 	8737 works in the r_2001779561 department, and was born in Naira.
# 	8736 works in the r_2001856268 department, and was born in Naira.
# 	8735 works in the r_11509532 department, and was born in Naira.
# 	8734 works in the r_8698869987 department, and was born in Naira.
# 	8733 works in the r_2001691055 department, and was born in Naira.
# 	8732 works in the r_2001548761 department, and was born in Naira.
# 	8731 works in the r_2002334437 department, and was born in Naira.
# 	8730 works in the r_2000830820 department, and was born in Naira.
# 	8729 works in the r_2002069881 department, and was born in Naira.
# 	8728 works in the r_10939413 department, and was born in Naira.
# 	8727 works in the r_10221596 department, and was born in Naira.
# 	8726 works in the r_2001582498 department, and was born in Naira.
# 	8725 works in the r_2001761664 department, and was born in Naira.
# 	8724 works in the r_2001785956 department, and was born in Naira.
# 	8723 works in the r_2002029650 department, and was born in Naira.
# 	8722 works in the r_2002190107 department, and was born in Naira.
# 	8721 works in the r_8698828412 department, and was born in Naira.
# 	8720 works in the r_2001742725 department, and was born in Naira.
# 	8719 works in the r_2001875166 department, and was born in Naira.
# 	8718 works in the r_8698811184 department, and was born in Naira.
# 	8717 works in the r_2000111291 department, and was born in Naira.
# 	8716 works in the r_8698830354 department, and was born in Naira.
# 	8715 works in the r_2001752112 department, and was born in Naira.
# 	8714 works in the r_2001864969 department, and was born in Naira.
# 	8713 works in the r_8698808945 department, and was born in Naira.
# 	8712 works in the r_2001661988 department, and was born in Naira.
# 	8711 works in the r_10670114 department, and was born in Naira.
# 	8710 works in the r_2000684613 department, and was born in Naira.
# 	8709 works in the r_11584577 department, and was born in Naira.
# 	8708 works in the r_10604361 department, and was born in Naira.
# 	8707 works in the r_2002276078 department, and was born in Naira.
# 	8706 works in the r_10471293 department, and was born in Naira.
# 	8705 works in the r_10002545 department, and was born in Naira.
# 	8704 works in the r_10766762 department, and was born in Naira.
# 	8703 works in the r_2001558807 department, and was born in Naira.
# 	8702 works in the r_11238540 department, and was born in Naira.
# 	8701 works in the r_10296765 department, and was born in Naira.
# 	8700 works in the r_2000347858 department, and was born in Naira.
# 	8699 works in the r_10874558 department, and was born in Naira.
# 	8698 works in the r_10187211 department, and was born in Naira.
# 	8697 works in the r_2001915390 department, and was born in Naira.
# 	8696 works in the r_11189709 department, and was born in Naira.
# 	8695 works in the r_2001605939 department, and was born in Naira.
# 	8694 works in the r_2001686733 department, and was born in Naira.
# 	8693 works in the r_2002426356 department, and was born in Naira.
# 	8692 works in the r_2001901739 department, and was born in Naira.
# 	8691 works in the r_2002166537 department, and was born in Naira.
# 	8690 works in the r_2000616832 department, and was born in Naira.
# 	8689 works in the r_2001843042 department, and was born in Naira.
# 	8688 works in the r_2001781799 department, and was born in Naira.
# 	8687 works in the r_2001915892 department, and was born in Naira.
# 	8686 works in the r_2002230391 department, and was born in Naira.
# 	8685 works in the r_2001804691 department, and was born in Naira.
# 	8684 works in the r_8698830168 department, and was born in Naira.
# 	8683 works in the r_10487951 department, and was born in Naira.
# 	8682 works in the r_2001640545 department, and was born in Naira.
# 	8681 works in the r_2002465200 department, and was born in Naira.
# 	8680 works in the r_2001543217 department, and was born in Naira.
# 	8679 works in the r_2000160102 department, and was born in Naira.
# 	8678 works in the r_2002181219 department, and was born in Naira.
# 	8677 works in the r_2001771277 department, and was born in Naira.
# 	8676 works in the r_2000313010 department, and was born in Naira.
# 	8675 works in the r_11581780 department, and was born in Naira.
# 	8674 works in the r_11084208 department, and was born in Naira.
# 	8673 works in the r_2001550227 department, and was born in Naira.
# 	8672 works in the r_2001568576 department, and was born in Naira.
# 	8671 works in the r_10179839 department, and was born in Naira.
# 	8670 works in the r_2001842690 department, and was born in Naira.
# 	8669 works in the r_10478779 department, and was born in Naira.
# 	8668 works in the r_2001876446 department, and was born in Naira.
# 	8667 works in the r_2001690885 department, and was born in Naira.
# 	8666 works in the r_8698860498 department, and was born in Naira.
# 	8665 works in the r_10337481 department, and was born in Naira.
# 	8664 works in the r_8698833861 department, and was born in Naira.
# 	8663 works in the r_2001557746 department, and was born in Naira.
# 	8662 works in the r_10365365 department, and was born in Naira.
# 	8661 works in the r_11497146 department, and was born in Naira.
# 	8660 works in the r_2001684419 department, and was born in Naira.
# 	8659 works in the r_2001889851 department, and was born in Naira.
# 	8658 works in the r_11016338 department, and was born in Naira.
# 	8657 works in the r_10852922 department, and was born in Naira.
# 	8656 works in the r_11684270 department, and was born in Naira.
# 	8655 works in the r_2000344433 department, and was born in Naira.
# 	8654 works in the r_8698831766 department, and was born in Naira.
# 	8653 works in the r_2001771092 department, and was born in Naira.
# 	8652 works in the r_10777815 department, and was born in Naira.
# 	8651 works in the r_2001767360 department, and was born in Naira.
# 	8650 works in the r_10908521 department, and was born in Naira.
# 	8649 works in the r_10085717 department, and was born in Naira.
# 	8648 works in the r_2002388631 department, and was born in Naira.
# 	8647 works in the r_11357957 department, and was born in Naira.
# 	8646 works in the r_8698846683 department, and was born in Naira.
# 	8645 works in the r_10884599 department, and was born in Naira.
# 	8644 works in the r_2001906350 department, and was born in Naira.
# 	8643 works in the r_2001789251 department, and was born in Naira.
# 	8642 works in the r_2001758242 department, and was born in Naira.
# 	8641 works in the r_2001892788 department, and was born in Naira.
# 	8640 works in the r_10613815 department, and was born in Naira.
# 	8639 works in the r_11631167 department, and was born in Naira.
# 	8638 works in the r_2001697298 department, and was born in Naira.
# 	8637 works in the r_10166522 department, and was born in Naira.
# 	8636 works in the r_2000833642 department, and was born in Naira.
# 	8635 works in the r_8698864453 department, and was born in Naira.
# 	8634 works in the r_11370330 department, and was born in Naira.
# 	8633 works in the r_10999437 department, and was born in Naira.
# 	8632 works in the r_2000791632 department, and was born in Naira.
# 	8631 works in the r_10381787 department, and was born in Naira.
# 	8630 works in the r_8698829171 department, and was born in Naira.
# 	8629 works in the r_8698864741 department, and was born in Naira.
# 	8628 works in the r_2002194419 department, and was born in Naira.
# 	8627 works in the r_11072569 department, and was born in Naira.
# 	8626 works in the r_2001753248 department, and was born in Naira.
# 	8625 works in the r_10467091 department, and was born in Naira.
# 	8624 works in the r_11544930 department, and was born in Naira.
# 	8623 works in the r_2001805403 department, and was born in Naira.
# 	8622 works in the r_10054551 department, and was born in Naira.
# 	8621 works in the r_11322583 department, and was born in Naira.
# 	8620 works in the r_2001624986 department, and was born in Naira.
# 	8619 works in the r_2002189939 department, and was born in Naira.
# 	8618 works in the r_11211441 department, and was born in Naira.
# 	8617 works in the r_2001550843 department, and was born in Naira.
# 	8616 works in the r_11577789 department, and was born in Naira.
# 	8615 works in the r_10846432 department, and was born in Naira.
# 	8614 works in the r_8698826300 department, and was born in Naira.
# 	8613 works in the r_10643445 department, and was born in Naira.
# 	8612 works in the r_10976745 department, and was born in Naira.
# 	8611 works in the r_8698854840 department, and was born in Naira.
# 	8610 works in the r_8698828727 department, and was born in Naira.
# 	8609 works in the r_2001675989 department, and was born in Naira.
# 	8608 works in the r_10335671 department, and was born in Naira.
# 	8607 works in the r_11657306 department, and was born in Naira.
# 	8606 works in the r_11054405 department, and was born in Naira.
# 	8605 works in the r_11435947 department, and was born in Naira.
# 	8604 works in the r_8698812252 department, and was born in Naira.
# 	8603 works in the r_2001569111 department, and was born in Naira.
# 	8602 works in the r_11684176 department, and was born in Naira.
# 	8601 works in the r_2001780053 department, and was born in Naira.
# 	8600 works in the r_10926586 department, and was born in Naira.
# 	8599 works in the r_10772055 department, and was born in Naira.
# 	8598 works in the r_11057130 department, and was born in Naira.
# 	8597 works in the r_2001626632 department, and was born in Naira.
# 	8596 works in the r_2000839719 department, and was born in Naira.
# 	8595 works in the r_10336038 department, and was born in Naira.
# 	8594 works in the r_10073678 department, and was born in Naira.
# 	8593 works in the r_10156760 department, and was born in Naira.
# 	8592 works in the r_11294006 department, and was born in Naira.
# 	8591 works in the r_10000778 department, and was born in Naira.
# 	8590 works in the r_2001919272 department, and was born in Naira.
# 	8589 works in the r_10613815 department, and was born in Naira.
# 	8588 works in the r_2000243679 department, and was born in Naira.
# 	8587 works in the r_10959858 department, and was born in Naira.
# 	8586 works in the r_2001837704 department, and was born in Naira.
# 	8585 works in the r_2001674945 department, and was born in Naira.
# 	8584 works in the r_2001020718 department, and was born in Naira.
# 	8583 works in the r_8698811904 department, and was born in Naira.
# 	8582 works in the r_8698803942 department, and was born in Naira.
# 	8581 works in the r_10456822 department, and was born in Naira.
# 	8580 works in the r_10564432 department, and was born in Naira.
# 	8579 works in the r_10035930 department, and was born in Naira.
# 	8578 works in the r_11283490 department, and was born in Naira.
# 	8577 works in the r_10007778 department, and was born in Naira.
# 	8576 works in the r_10352066 department, and was born in Naira.
# 	8575 works in the r_8698824239 department, and was born in Naira.
# 	8574 works in the r_2001691937 department, and was born in Naira.
# 	8573 works in the r_10816221 department, and was born in Naira.
# 	8572 works in the r_2000804291 department, and was born in Naira.
# 	8571 works in the r_2000486461 department, and was born in Naira.
# 	8570 works in the r_10776780 department, and was born in Naira.
# 	8569 works in the r_11045974 department, and was born in Naira.
# 	8568 works in the r_10917558 department, and was born in Naira.
# 	8567 works in the r_10734986 department, and was born in Naira.
# 	8566 works in the r_11591094 department, and was born in Naira.
# 	8565 works in the r_10896803 department, and was born in Naira.
# 	8564 works in the r_2002002160 department, and was born in Naira.
# 	8563 works in the r_11296769 department, and was born in Naira.
# 	8562 works in the r_2001591429 department, and was born in Naira.
# 	8561 works in the r_2001979708 department, and was born in Naira.
# 	8560 works in the r_2001708298 department, and was born in Naira.
# 	8559 works in the r_2001744480 department, and was born in Naira.
# 	8558 works in the r_2000729019 department, and was born in Naira.
# 	8557 works in the r_8698806794 department, and was born in Naira.
# 	8556 works in the r_11497271 department, and was born in Naira.
# 	8555 works in the r_11004101 department, and was born in Naira.
# 	8554 works in the r_8698830144 department, and was born in Naira.
# 	8553 works in the r_2000963003 department, and was born in Naira.
# 	8552 works in the r_2001968213 department, and was born in Naira.
# 	8551 works in the r_10126908 department, and was born in Naira.
# 	8550 works in the r_10857514 department, and was born in Naira.
# 	8549 works in the r_11539702 department, and was born in Naira.
# 	8548 works in the r_11419908 department, and was born in Naira.
# 	8547 works in the r_10537730 department, and was born in Naira.
# 	8546 works in the r_10886371 department, and was born in Naira.
# 	8545 works in the r_10464574 department, and was born in Naira.
# 	8544 works in the r_10897817 department, and was born in Naira.
# 	8543 works in the r_10050468 department, and was born in Naira.
# 	8542 works in the r_2001771671 department, and was born in Naira.
# 	8541 works in the r_10107626 department, and was born in Naira.
# 	8540 works in the r_11696490 department, and was born in Naira.
# 	8539 works in the r_11020681 department, and was born in Naira.
# 	8538 works in the r_2001776306 department, and was born in Naira.
# 	8537 works in the r_10480082 department, and was born in Naira.
# 	8536 works in the r_2000832794 department, and was born in Naira.
# 	8535 works in the r_11625770 department, and was born in Naira.
# 	8534 works in the r_2002167046 department, and was born in Naira.
# 	8533 works in the r_8698844005 department, and was born in Naira.
# 	8532 works in the r_10060152 department, and was born in Naira.
# 	8531 works in the r_2001040846 department, and was born in Naira.
# 	8530 works in the r_10938372 department, and was born in Naira.
# 	8529 works in the r_10519948 department, and was born in Naira.
# 	8528 works in the r_10949844 department, and was born in Naira.
# 	8527 works in the r_2001966139 department, and was born in Naira.
# 	8526 works in the r_8698840958 department, and was born in Naira.
# 	8525 works in the r_2002164780 department, and was born in Naira.
# 	8524 works in the r_2001829728 department, and was born in Naira.
# 	8523 works in the r_2001641679 department, and was born in Naira.
# 	8522 works in the r_2001783698 department, and was born in Naira.
# 	8521 works in the r_2000299651 department, and was born in Naira.
# 	8520 works in the r_2001763563 department, and was born in Naira.
# 	8519 works in the r_11537257 department, and was born in Naira.
# 	8518 works in the r_2002101527 department, and was born in Naira.
# 	8517 works in the r_2001792318 department, and was born in Naira.
# 	8516 works in the r_11446613 department, and was born in Naira.
# 	8515 works in the r_10726558 department, and was born in Naira.
# 	8514 works in the r_11243958 department, and was born in Naira.
# 	8513 works in the r_2002185916 department, and was born in Naira.
# 	8512 works in the r_10510344 department, and was born in Naira.
# 	8511 works in the r_10093820 department, and was born in Naira.
# 	8510 works in the r_10790094 department, and was born in Naira.
# 	8509 works in the r_2001931491 department, and was born in Naira.
# 	8508 works in the r_2002262895 department, and was born in Naira.
# 	8507 works in the r_8698870055 department, and was born in Naira.
# 	8506 works in the r_10246034 department, and was born in Naira.
# 	8505 works in the r_10296765 department, and was born in Naira.
# 	8504 works in the r_10173987 department, and was born in Naira.
# 	8503 works in the r_11004101 department, and was born in Naira.
# 	8502 works in the r_10856783 department, and was born in Naira.
# 	8501 works in the r_2000234957 department, and was born in Naira.
# 	8500 works in the r_10381787 department, and was born in Naira.
# 	8499 works in the r_2001780053 department, and was born in Naira.
# 	8498 works in the r_10852922 department, and was born in Naira.
# 	8497 works in the r_2001751699 department, and was born in Naira.
# 	8496 works in the r_10910165 department, and was born in Naira.
# 	8495 works in the r_2001810150 department, and was born in Naira.
# 	8494 works in the r_11150928 department, and was born in Naira.
# 	8493 works in the r_2002101527 department, and was born in Naira.
# 	8492 works in the r_2001020718 department, and was born in Naira.
# 	8491 works in the r_2001674017 department, and was born in Naira.
# 	8490 works in the r_11684270 department, and was born in Naira.
# 	8489 works in the r_11491329 department, and was born in Naira.
# 	8488 works in the r_10101727 department, and was born in Naira.
# 	8487 works in the r_8698861197 department, and was born in Naira.
# 	8486 works in the r_8698850329 department, and was born in Naira.
# 	8485 works in the r_10199777 department, and was born in Naira.
# 	8484 works in the r_2000499713 department, and was born in Naira.
# 	8483 works in the r_2002185916 department, and was born in Naira.
# 	8482 works in the r_8698856725 department, and was born in Naira.
# 	8481 works in the r_10993116 department, and was born in Naira.
# 	8480 works in the r_10514706 department, and was born in Naira.
# 	8479 works in the r_8698850247 department, and was born in Naira.
# 	8478 works in the r_11571152 department, and was born in Naira.
# 	8477 works in the r_2001675800 department, and was born in Naira.
# 	8476 works in the r_10628920 department, and was born in Naira.
# 	8475 works in the r_10204939 department, and was born in Naira.
# 	8474 works in the r_10589808 department, and was born in Naira.
# 	8473 works in the r_2001844514 department, and was born in Naira.
# 	8472 works in the r_10161716 department, and was born in Naira.
# 	8471 works in the r_8698867753 department, and was born in Naira.
# 	8470 works in the r_10480082 department, and was born in Naira.
# 	8469 works in the r_10496743 department, and was born in Naira.
# 	8468 works in the r_2001634189 department, and was born in Naira.
# 	8467 works in the r_11054484 department, and was born in Naira.
# 	8466 works in the r_2002189939 department, and was born in Naira.
# 	8465 works in the r_10037195 department, and was born in Naira.
# 	8464 works in the r_10218853 department, and was born in Naira.
# 	8463 works in the r_11317294 department, and was born in Naira.
# 	8462 works in the r_10464774 department, and was born in Naira.
# 	8461 works in the r_11147429 department, and was born in Naira.
# 	8460 works in the r_8698862751 department, and was born in Naira.
# 	8459 works in the r_11105568 department, and was born in Naira.
# 	8458 works in the r_11499579 department, and was born in Naira.
# 	8457 works in the r_11059128 department, and was born in Naira.
# 	8456 works in the r_8698839709 department, and was born in Naira.
# 	8455 works in the r_11243324 department, and was born in Naira.
# 	8454 works in the r_2002185916 department, and was born in Naira.
# 	8453 works in the r_2001883184 department, and was born in Naira.
# 	8452 works in the r_10603949 department, and was born in Naira.
# 	8451 works in the r_11010704 department, and was born in Naira.
# 	8450 works in the r_8698863253 department, and was born in Naira.
# 	8449 works in the r_8698866601 department, and was born in Naira.
# 	8448 works in the r_10577654 department, and was born in Naira.
# 	8447 works in the r_11064484 department, and was born in Naira.
# 	8446 works in the r_10832837 department, and was born in Naira.
# 	8445 works in the r_2001563412 department, and was born in Naira.
# 	8444 works in the r_11406380 department, and was born in Naira.
# 	8443 works in the r_10850326 department, and was born in Naira.
# 	8442 works in the r_2000339072 department, and was born in Naira.
# 	8441 works in the r_8698805944 department, and was born in Naira.
# 	8440 works in the r_2001930431 department, and was born in Naira.
# 	8439 works in the r_11016458 department, and was born in Naira.
# 	8438 works in the r_8698832828 department, and was born in Naira.
# 	8437 works in the r_2001689155 department, and was born in Naira.
# 	8436 works in the r_2001991165 department, and was born in Naira.
# 	8435 works in the r_10992800 department, and was born in Naira.
# 	8434 works in the r_2001539543 department, and was born in Naira.
# 	8433 works in the r_2000831885 department, and was born in Naira.
# 	8432 works in the r_11230871 department, and was born in Naira.
# 	8431 works in the r_11518358 department, and was born in Naira.
# 	8430 works in the r_2000016305 department, and was born in Naira.
# 	8429 works in the r_2001661499 department, and was born in Naira.
# 	8428 works in the r_2000023706 department, and was born in Naira.
# 	8427 works in the r_8698813049 department, and was born in Naira.
# 	8426 works in the r_8698856530 department, and was born in Naira.
# 	8425 works in the r_2001899379 department, and was born in Naira.
# 	8424 works in the r_11500685 department, and was born in Naira.
# 	8423 works in the r_8698811871 department, and was born in Naira.
# 	8422 works in the r_11589955 department, and was born in Naira.
# 	8421 works in the r_11376609 department, and was born in Naira.
# 	8420 works in the r_11090332 department, and was born in Naira.
# 	8419 works in the r_2002170583 department, and was born in Naira.
# 	8418 works in the r_10312090 department, and was born in Naira.
# 	8417 works in the r_2001543088 department, and was born in Naira.
# 	8416 works in the r_11470504 department, and was born in Naira.
# 	8415 works in the r_8698844840 department, and was born in Naira.
# 	8414 works in the r_11025528 department, and was born in Naira.
# 	8413 works in the r_2001847293 department, and was born in Naira.
# 	8412 works in the r_2001769799 department, and was born in Naira.
# 	8411 works in the r_2000307535 department, and was born in Naira.
# 	8410 works in the r_2001656783 department, and was born in Naira.
# 	8409 works in the r_11007308 department, and was born in Naira.
# 	8408 works in the r_8698856458 department, and was born in Naira.
# 	8407 works in the r_8698868557 department, and was born in Naira.
# 	8406 works in the r_2000685494 department, and was born in Naira.
# 	8405 works in the r_2002175398 department, and was born in Naira.
# 	8404 works in the r_2001707670 department, and was born in Naira.
# 	8403 works in the r_10358311 department, and was born in Naira.
# 	8402 works in the r_10013291 department, and was born in Naira.
# 	8401 works in the r_10800305 department, and was born in Naira.
# 	8400 works in the r_2001860767 department, and was born in Naira.
# 	8399 works in the r_10871334 department, and was born in Naira.
# 	8398 works in the r_2002185234 department, and was born in Naira.
# 	8397 works in the r_2001740148 department, and was born in Naira.
# 	8396 works in the r_10871163 department, and was born in Naira.
# 	8395 works in the r_2001810462 department, and was born in Naira.
# 	8394 works in the r_11258605 department, and was born in Naira.
# 	8393 works in the r_2001645711 department, and was born in Naira.
# 	8392 works in the r_10802079 department, and was born in Naira.
# 	8391 works in the r_10675184 department, and was born in Naira.
# 	8390 works in the r_10701512 department, and was born in Naira.
# 	8389 works in the r_11256867 department, and was born in Naira.
# 	8388 works in the r_8698857996 department, and was born in Naira.
# 	8387 works in the r_8698861975 department, and was born in Naira.
# 	8386 works in the r_8698822112 department, and was born in Naira.
# 	8385 works in the r_2002194543 department, and was born in Naira.
# 	8384 works in the r_11135961 department, and was born in Naira.
# 	8383 works in the r_2001839936 department, and was born in Naira.
# 	8382 works in the r_8698820565 department, and was born in Naira.
# 	8381 works in the r_10022385 department, and was born in Naira.
# 	8380 works in the r_2001858857 department, and was born in Naira.
# 	8379 works in the r_10504401 department, and was born in Naira.
# 	8378 works in the r_10962664 department, and was born in Naira.
# 	8377 works in the r_10977536 department, and was born in Naira.
# 	8376 works in the r_11165460 department, and was born in Naira.
# 	8375 works in the r_2001665728 department, and was born in Naira.
# 	8374 works in the r_10744874 department, and was born in Naira.
# 	8373 works in the r_2002175267 department, and was born in Naira.
# 	8372 works in the r_8698817572 department, and was born in Naira.
# 	8371 works in the r_2001775876 department, and was born in Naira.
# 	8370 works in the r_11165781 department, and was born in Naira.
# 	8369 works in the r_8698828455 department, and was born in Naira.
# 	8368 works in the r_10351727 department, and was born in Naira.
# 	8367 works in the r_2001934120 department, and was born in Naira.
# 	8366 works in the r_10274438 department, and was born in Naira.
# 	8365 works in the r_8698837713 department, and was born in Naira.
# 	8364 works in the r_10698636 department, and was born in Naira.
# 	8363 works in the r_2002032034 department, and was born in Naira.
# 	8362 works in the r_8698811871 department, and was born in Naira.
# 	8361 works in the r_8698864395 department, and was born in Naira.
# 	8360 works in the r_10964472 department, and was born in Naira.
# 	8359 works in the r_11498975 department, and was born in Naira.
# 	8358 works in the r_8698815633 department, and was born in Naira.
# 	8357 works in the r_2001742030 department, and was born in Naira.
# 	8356 works in the r_8698821509 department, and was born in Naira.
# 	8355 works in the r_11310107 department, and was born in Naira.
# 	8354 works in the r_10393647 department, and was born in Naira.
# 	8353 works in the r_11579724 department, and was born in Naira.
# 	8352 works in the r_11645923 department, and was born in Naira.
# 	8351 works in the r_10844382 department, and was born in Naira.
# 	8350 works in the r_2001546530 department, and was born in Naira.
# 	8349 works in the r_2000350807 department, and was born in Naira.
# 	8348 works in the r_8698832909 department, and was born in Naira.
# 	8347 works in the r_2000963995 department, and was born in Naira.
# 	8346 works in the r_10653516 department, and was born in Naira.
# 	8345 works in the r_11617500 department, and was born in Naira.
# 	8344 works in the r_2001656783 department, and was born in Naira.
# 	8343 works in the r_11673113 department, and was born in Naira.
# 	8342 works in the r_2002174027 department, and was born in Naira.
# 	8341 works in the r_2002488669 department, and was born in Naira.
# 	8340 works in the r_10704480 department, and was born in Naira.
# 	8339 works in the r_2001827880 department, and was born in Naira.
# 	8338 works in the r_10203046 department, and was born in Naira.
# 	8337 works in the r_11121545 department, and was born in Naira.
# 	8336 works in the r_11576304 department, and was born in Naira.
# 	8335 works in the r_2001637367 department, and was born in Naira.
# 	8334 works in the r_10590033 department, and was born in Naira.
# 	8333 works in the r_10680647 department, and was born in Naira.
# 	8332 works in the r_2002372164 department, and was born in Naira.
# 	8331 works in the r_2001810120 department, and was born in Naira.
# 	8330 works in the r_10913388 department, and was born in Naira.
# 	8329 works in the r_2001537566 department, and was born in Naira.
# 	8328 works in the r_10391518 department, and was born in Naira.
# 	8327 works in the r_10451099 department, and was born in Naira.
# 	8326 works in the r_11350136 department, and was born in Naira.
# 	8325 works in the r_2001939874 department, and was born in Naira.
# 	8324 works in the r_11166094 department, and was born in Naira.
# 	8323 works in the r_2001878907 department, and was born in Naira.
# 	8322 works in the r_10486348 department, and was born in Naira.
# 	8321 works in the r_10621992 department, and was born in Naira.
# 	8320 works in the r_2000690668 department, and was born in Naira.
# 	8319 works in the r_11602267 department, and was born in Naira.
# 	8318 works in the r_2000838830 department, and was born in Naira.
# 	8317 works in the r_11118848 department, and was born in Naira.
# 	8316 works in the r_2001579467 department, and was born in Naira.
# 	8315 works in the r_2001626148 department, and was born in Naira.
# 	8314 works in the r_10621549 department, and was born in Naira.
# 	8313 works in the r_2002179666 department, and was born in Naira.
# 	8312 works in the r_2002187771 department, and was born in Naira.
# 	8311 works in the r_8698843948 department, and was born in Naira.
# 	8310 works in the r_10795471 department, and was born in Naira.
# 	8309 works in the r_10573109 department, and was born in Naira.
# 	8308 works in the r_8698837486 department, and was born in Naira.
# 	8307 works in the r_10625230 department, and was born in Naira.
# 	8306 works in the r_10647096 department, and was born in Naira.
# 	8305 works in the r_11203787 department, and was born in Naira.
# 	8304 works in the r_2001583792 department, and was born in Naira.
# 	8303 works in the r_2000975420 department, and was born in Naira.
# 	8302 works in the r_10519194 department, and was born in Naira.
# 	8301 works in the r_10135168 department, and was born in Naira.
# 	8300 works in the r_2001884061 department, and was born in Naira.
# 	8299 works in the r_2001811669 department, and was born in Naira.
# 	8298 works in the r_2001844393 department, and was born in Naira.
# 	8297 works in the r_2002328340 department, and was born in Naira.
# 	8296 works in the r_11211430 department, and was born in Naira.
# 	8295 works in the r_10139093 department, and was born in Naira.
# 	8294 works in the r_2001840221 department, and was born in Naira.
# 	8293 works in the r_2002263946 department, and was born in Naira.
# 	8292 works in the r_10213205 department, and was born in Naira.
# 	8291 works in the r_8698834841 department, and was born in Naira.
# 	8290 works in the r_11086094 department, and was born in Naira.
# 	8289 works in the r_2000791644 department, and was born in Naira.
# 	8288 works in the r_8698849224 department, and was born in Naira.
# 	8287 works in the r_10729019 department, and was born in Naira.
# 	8286 works in the r_8698827783 department, and was born in Naira.
# 	8285 works in the r_2001537874 department, and was born in Naira.
# 	8284 works in the r_10332885 department, and was born in Naira.
# 	8283 works in the r_10971294 department, and was born in Naira.
# 	8282 works in the r_10696857 department, and was born in Naira.
# 	8281 works in the r_8698844810 department, and was born in Naira.
# 	8280 works in the r_2001790696 department, and was born in Naira.
# 	8279 works in the r_2001950732 department, and was born in Naira.
# 	8278 works in the r_2002167015 department, and was born in Naira.
# 	8277 works in the r_2001952045 department, and was born in Naira.
# 	8276 works in the r_2001988153 department, and was born in Naira.
# 	8275 works in the r_2001564801 department, and was born in Naira.
# 	8274 works in the r_2001939874 department, and was born in Naira.
# 	8273 works in the r_10701370 department, and was born in Naira.
# 	8272 works in the r_11482631 department, and was born in Naira.
# 	8271 works in the r_11230629 department, and was born in Naira.
# 	8270 works in the r_10099928 department, and was born in Naira.
# 	8269 works in the r_10519087 department, and was born in Naira.
# 	8268 works in the r_2001990880 department, and was born in Naira.
# 	8267 works in the r_8698807599 department, and was born in Naira.
# 	8266 works in the r_8698833216 department, and was born in Naira.
# 	8265 works in the r_8698846795 department, and was born in Naira.
# 	8264 works in the r_8698856254 department, and was born in Naira.
# 	8263 works in the r_2001600699 department, and was born in Naira.
# 	8262 works in the r_8698860289 department, and was born in Naira.
# 	8261 works in the r_2001542564 department, and was born in Naira.
# 	8260 works in the r_11283568 department, and was born in Naira.
# 	8259 works in the r_2000289163 department, and was born in Naira.
# 	8258 works in the r_10511275 department, and was born in Naira.
# 	8257 works in the r_10732079 department, and was born in Naira.
# 	8256 works in the r_11057094 department, and was born in Naira.
# 	8255 works in the r_8698815921 department, and was born in Naira.
# 	8254 works in the r_2000218828 department, and was born in Naira.
# 	8253 works in the r_10478749 department, and was born in Naira.
# 	8252 works in the r_2002165143 department, and was born in Naira.
# 	8251 works in the r_2001674852 department, and was born in Naira.
# 	8250 works in the r_2001984370 department, and was born in Naira.
# 	8249 works in the r_10001512 department, and was born in Naira.
# 	8248 works in the r_2002012127 department, and was born in Naira.
# 	8247 works in the r_2001686772 department, and was born in Naira.
# 	8246 works in the r_10486295 department, and was born in Naira.
# 	8245 works in the r_11671473 department, and was born in Naira.
# 	8244 works in the r_10687074 department, and was born in Naira.
# 	8243 works in the r_2002163500 department, and was born in Naira.
# 	8242 works in the r_2001361104 department, and was born in Naira.
# 	8241 works in the r_8698822112 department, and was born in Naira.
# 	8240 works in the r_10590538 department, and was born in Naira.
# 	8239 works in the r_11483566 department, and was born in Naira.
# 	8238 works in the r_2001987213 department, and was born in Naira.
# 	8237 works in the r_2002168158 department, and was born in Naira.
# 	8236 works in the r_11597867 department, and was born in Naira.
# 	8235 works in the r_10761613 department, and was born in Naira.
# 	8234 works in the r_10072517 department, and was born in Naira.
# 	8233 works in the r_11486392 department, and was born in Naira.
# 	8232 works in the r_2001936079 department, and was born in Naira.
# 	8231 works in the r_11616323 department, and was born in Naira.
# 	8230 works in the r_2001829497 department, and was born in Naira.
# 	8229 works in the r_11217065 department, and was born in Naira.
# 	8228 works in the r_2001939874 department, and was born in Naira.
# 	8227 works in the r_10770675 department, and was born in Naira.
# 	8226 works in the r_11669943 department, and was born in Naira.
# 	8225 works in the r_2001692184 department, and was born in Naira.
# 	8224 works in the r_2002168731 department, and was born in Naira.
# 	8223 works in the r_10797177 department, and was born in Naira.
# 	8222 works in the r_10645013 department, and was born in Naira.
# 	8221 works in the r_11531713 department, and was born in Naira.
# 	8220 works in the r_2001800534 department, and was born in Naira.
# 	8219 works in the r_2000628743 department, and was born in Naira.
# 	8218 works in the r_8698847824 department, and was born in Naira.
# 	8217 works in the r_2001998681 department, and was born in Naira.
# 	8216 works in the r_8698858442 department, and was born in Naira.
# 	8215 works in the r_2001802763 department, and was born in Naira.
# 	8214 works in the r_10137432 department, and was born in Naira.
# 	8213 works in the r_11310296 department, and was born in Naira.
# 	8212 works in the r_2001922249 department, and was born in Naira.
# 	8211 works in the r_2001805042 department, and was born in Naira.
# 	8210 works in the r_8698867729 department, and was born in Naira.
# 	8209 works in the r_8698805922 department, and was born in Naira.
# 	8208 works in the r_2000850415 department, and was born in Naira.
# 	8207 works in the r_11258691 department, and was born in Naira.
# 	8206 works in the r_2001753559 department, and was born in Naira.
# 	8205 works in the r_8698862535 department, and was born in Naira.
# 	8204 works in the r_10088837 department, and was born in Naira.
# 	8203 works in the r_11457557 department, and was born in Naira.
# 	8202 works in the r_10705652 department, and was born in Naira.
# 	8201 works in the r_2001837678 department, and was born in Naira.
# 	8200 works in the r_11281880 department, and was born in Naira.
# 	8199 works in the r_10644312 department, and was born in Naira.
# 	8198 works in the r_10020048 department, and was born in Naira.
# 	8197 works in the r_2000290080 department, and was born in Naira.
# 	8196 works in the r_2002070214 department, and was born in Naira.
# 	8195 works in the r_10173764 department, and was born in Naira.
# 	8194 works in the r_10577517 department, and was born in Naira.
# 	8193 works in the r_10042262 department, and was born in Naira.
# 	8192 works in the r_2002075278 department, and was born in Naira.
# 	8191 works in the r_2000788873 department, and was born in Naira.
# 	8190 works in the r_11123570 department, and was born in Naira.
# ...
# 	251 works in the r_10697169 department, and was born in Naira.
# 	250 works in the r_2002178108 department, and was born in Naira.
# 	249 works in the r_10631678 department, and was born in Naira.
# 	248 works in the r_2001542181 department, and was born in Naira.
# 	247 works in the r_2000104176 department, and was born in Naira.
# 	246 works in the r_10308421 department, and was born in Naira.
# 	245 works in the r_2001801086 department, and was born in Naira.
# 	244 works in the r_2001689162 department, and was born in Naira.
# 	243 works in the r_10871095 department, and was born in Naira.
# 	242 works in the r_10338190 department, and was born in Naira.
# 	241 works in the r_2001365422 department, and was born in Naira.
# 	240 works in the r_11258605 department, and was born in Naira.
# 	239 works in the r_10100003 department, and was born in Naira.
# 	238 works in the r_2000323854 department, and was born in Naira.
# 	237 works in the r_2000422164 department, and was born in Naira.
# 	236 works in the r_11643889 department, and was born in Naira.
# 	235 works in the r_2001783629 department, and was born in Naira.
# 	234 works in the r_10458150 department, and was born in Naira.
# 	233 works in the r_11668598 department, and was born in Naira.
# 	232 works in the r_2000321340 department, and was born in Naira.
# 	231 works in the r_11105797 department, and was born in Naira.
# 	230 works in the r_2001796218 department, and was born in Naira.
# 	229 works in the r_11150201 department, and was born in Naira.
# 	228 works in the r_10992697 department, and was born in Naira.
# 	227 works in the r_2001840891 department, and was born in Naira.
# 	226 works in the r_10924471 department, and was born in Naira.
# 	225 works in the r_11030638 department, and was born in Naira.
# 	224 works in the r_2000289470 department, and was born in Naira.
# 	223 works in the r_2001043008 department, and was born in Naira.
# 	222 works in the r_2001611405 department, and was born in Naira.
# 	221 works in the r_11510152 department, and was born in Naira.
# 	220 works in the r_10619850 department, and was born in Naira.
# 	219 works in the r_2000024152 department, and was born in Naira.
# 	218 works in the r_2001041938 department, and was born in Naira.
# 	217 works in the r_2000423024 department, and was born in Naira.
# 	216 works in the r_10937484 department, and was born in Naira.
# 	215 works in the r_10524654 department, and was born in Naira.
# 	214 works in the r_11350430 department, and was born in Naira.
# 	213 works in the r_10989809 department, and was born in Naira.
# 	212 works in the r_2001888134 department, and was born in Naira.
# 	211 works in the r_2001843380 department, and was born in Naira.
# 	210 works in the r_2001987955 department, and was born in Naira.
# 	209 works in the r_2001895214 department, and was born in Naira.
# 	208 works in the r_10192678 department, and was born in Naira.
# 	207 works in the r_2000977543 department, and was born in Naira.
# 	206 works in the r_10813033 department, and was born in Naira.
# 	205 works in the r_11639147 department, and was born in Naira.
# 	204 works in the r_10444595 department, and was born in Naira.
# 	203 works in the r_2001730774 department, and was born in Naira.
# 	202 works in the r_2002167821 department, and was born in Naira.
# 	201 works in the r_2001864582 department, and was born in Naira.
# 	200 works in the r_10020588 department, and was born in Naira.
# 	199 works in the r_11418543 department, and was born in Naira.
# 	198 works in the r_10909988 department, and was born in Naira.
# 	197 works in the r_2001838459 department, and was born in Naira.
# 	196 works in the r_10076680 department, and was born in Naira.
# 	195 works in the r_2001783631 department, and was born in Naira.
# 	194 works in the r_11697419 department, and was born in Naira.
# 	193 works in the r_2001656382 department, and was born in Naira.
# 	192 works in the r_2001793838 department, and was born in Naira.
# 	191 works in the r_2001042943 department, and was born in Naira.
# 	190 works in the r_2000220599 department, and was born in Naira.
# 	189 works in the r_2000222476 department, and was born in Naira.
# 	188 works in the r_2002165421 department, and was born in Naira.
# 	187 works in the r_2000227825 department, and was born in Naira.
# 	186 works in the r_10243344 department, and was born in Naira.
# 	185 works in the r_10126519 department, and was born in Naira.
# 	184 works in the r_2001784191 department, and was born in Naira.
# 	183 works in the r_2000787030 department, and was born in Naira.
# 	182 works in the r_2000311311 department, and was born in Naira.
# 	181 works in the r_2001739113 department, and was born in Naira.
# 	180 works in the r_2002177418 department, and was born in Naira.
# 	179 works in the r_11270479 department, and was born in Naira.
# 	178 works in the r_2000218775 department, and was born in Naira.
# 	177 works in the r_2001372096 department, and was born in Naira.
# 	176 works in the r_11697415 department, and was born in Naira.
# 	175 works in the r_2000104176 department, and was born in Naira.
# 	174 works in the r_2001992770 department, and was born in Naira.
# 	173 works in the r_10870645 department, and was born in Naira.
# 	172 works in the r_11096873 department, and was born in Naira.
# 	171 works in the r_2001778606 department, and was born in Naira.
# 	170 works in the r_2000024640 department, and was born in Naira.
# 	169 works in the r_2002192603 department, and was born in Naira.
# 	168 works in the r_2000422094 department, and was born in Naira.
# 	167 works in the r_11110511 department, and was born in Naira.
# 	166 works in the r_2000633153 department, and was born in Naira.
# 	165 works in the r_2002194001 department, and was born in Naira.
# 	164 works in the r_10764416 department, and was born in Naira.
# 	163 works in the r_2001866053 department, and was born in Naira.
# 	162 works in the r_2000421290 department, and was born in Naira.
# 	161 works in the r_2002173406 department, and was born in Naira.
# 	160 works in the r_11140801 department, and was born in Naira.
# 	159 works in the r_2000588240 department, and was born in Naira.
# 	158 works in the r_2001931282 department, and was born in Naira.
# 	157 works in the r_2002167342 department, and was born in Naira.
# 	156 works in the r_2001737355 department, and was born in Naira.
# 	155 works in the r_2001544146 department, and was born in Naira.
# 	154 works in the r_2001985462 department, and was born in Naira.
# 	153 works in the r_11005113 department, and was born in Naira.
# 	152 works in the r_2000099793 department, and was born in Naira.
# 	151 works in the r_10047009 department, and was born in Naira.
# 	150 works in the r_11119224 department, and was born in Naira.
# 	149 works in the r_2000220622 department, and was born in Naira.
# 	148 works in the r_2001988679 department, and was born in Naira.
# 	147 works in the r_2000963092 department, and was born in Naira.
# 	146 works in the r_11165778 department, and was born in Naira.
# 	145 works in the r_10099848 department, and was born in Naira.
# 	144 works in the r_10055319 department, and was born in Naira.
# 	143 works in the r_10206495 department, and was born in Naira.
# 	142 works in the r_2001806187 department, and was born in Naira.
# 	141 works in the r_2000489379 department, and was born in Naira.
# 	140 works in the r_2002038861 department, and was born in Naira.
# 	139 works in the r_10252864 department, and was born in Naira.
# 	138 works in the r_10239061 department, and was born in Naira.
# 	137 works in the r_10990673 department, and was born in Naira.
# 	136 works in the r_2000710586 department, and was born in Naira.
# 	135 works in the r_11037758 department, and was born in Naira.
# 	134 works in the r_2001861153 department, and was born in Naira.
# 	133 works in the r_10034495 department, and was born in Naira.
# 	132 works in the r_10115564 department, and was born in Naira.
# 	131 works in the r_2000468347 department, and was born in Naira.
# 	130 works in the r_11323612 department, and was born in Naira.
# 	129 works in the r_10155578 department, and was born in Naira.
# 	128 works in the r_10986085 department, and was born in Naira.
# 	127 works in the r_2002170281 department, and was born in Naira.
# 	126 works in the r_2001580699 department, and was born in Naira.
# 	125 works in the r_2001898263 department, and was born in Naira.
# 	124 works in the r_2001370812 department, and was born in Naira.
# 	123 works in the r_2000224284 department, and was born in Naira.
# 	122 works in the r_10360196 department, and was born in Naira.
# 	121 works in the r_10605241 department, and was born in Naira.
# 	120 works in the r_2000302453 department, and was born in Naira.
# 	119 works in the r_2002172426 department, and was born in Naira.
# 	118 works in the r_10937750 department, and was born in Naira.
# 	117 works in the r_10113308 department, and was born in Naira.
# 	116 works in the r_2002042575 department, and was born in Naira.
# 	115 works in the r_2002170496 department, and was born in Naira.
# 	114 works in the r_10364821 department, and was born in Naira.
# 	113 works in the r_10073123 department, and was born in Naira.
# 	112 works in the r_10336038 department, and was born in Naira.
# 	111 works in the r_11363379 department, and was born in Naira.
# 	110 works in the r_10252186 department, and was born in Naira.
# 	109 works in the r_11216260 department, and was born in Naira.
# 	108 works in the r_2001622882 department, and was born in Naira.
# 	107 works in the r_2001630851 department, and was born in Naira.
# 	106 works in the r_10711516 department, and was born in Naira.
# 	105 works in the r_2001967399 department, and was born in Naira.
# 	104 works in the r_2001827278 department, and was born in Naira.
# 	103 works in the r_10050772 department, and was born in Naira.
# 	102 works in the r_2001905439 department, and was born in Naira.
# 	101 works in the r_2002177421 department, and was born in Naira.
# 	100 works in the r_2002192438 department, and was born in Naira.
# 	99 works in the r_2002179553 department, and was born in Naira.
# 	98 works in the r_2001984289 department, and was born in Naira.
# 	97 works in the r_10192819 department, and was born in Naira.
# 	96 works in the r_10870645 department, and was born in Naira.
# 	95 works in the r_11268552 department, and was born in Naira.
# 	94 works in the r_10384962 department, and was born in Naira.
# 	93 works in the r_2002036666 department, and was born in Naira.
# 	92 works in the r_10511190 department, and was born in Naira.
# 	91 works in the r_2002186079 department, and was born in Naira.
# 	90 works in the r_10775207 department, and was born in Naira.
# 	89 works in the r_2000043486 department, and was born in Naira.
# 	88 works in the r_11256993 department, and was born in Naira.
# 	87 works in the r_10033330 department, and was born in Naira.
# 	86 works in the r_10792805 department, and was born in Naira.
# 	85 works in the r_10967189 department, and was born in Naira.
# 	84 works in the r_10777480 department, and was born in Naira.
# 	83 works in the r_2001927194 department, and was born in Naira.
# 	82 works in the r_11090332 department, and was born in Naira.
# 	81 works in the r_11492350 department, and was born in Naira.
# 	80 works in the r_2001952961 department, and was born in Naira.
# 	79 works in the r_2002167673 department, and was born in Naira.
# 	78 works in the r_10337886 department, and was born in Naira.
# 	77 works in the r_11496710 department, and was born in Naira.
# 	76 works in the r_11116512 department, and was born in Naira.
# 	75 works in the r_11483564 department, and was born in Naira.
# 	74 works in the r_11680188 department, and was born in Naira.
# 	73 works in the r_11283956 department, and was born in Naira.
# 	72 works in the r_11439216 department, and was born in Naira.
# 	71 works in the r_10470477 department, and was born in Naira.
# 	70 works in the r_2001662588 department, and was born in Naira.
# 	69 works in the r_2001729185 department, and was born in Naira.
# 	68 works in the r_2001046280 department, and was born in Naira.
# 	67 works in the r_2001865979 department, and was born in Naira.
# 	66 works in the r_11179843 department, and was born in Naira.
# 	65 works in the r_2001609543 department, and was born in Naira.
# 	64 works in the r_2001797187 department, and was born in Naira.
# 	63 works in the r_10342628 department, and was born in Naira.
# 	62 works in the r_11033541 department, and was born in Naira.
# 	61 works in the r_2000234806 department, and was born in Naira.
# 	60 works in the r_2000263948 department, and was born in Naira.
# 	59 works in the r_10142655 department, and was born in Naira.
# 	58 works in the r_2001045087 department, and was born in Naira.
# 	57 works in the r_10166476 department, and was born in Naira.
# 	56 works in the r_10007566 department, and was born in Naira.
# 	55 works in the r_2001941684 department, and was born in Naira.
# 	54 works in the r_2002174997 department, and was born in Naira.
# 	53 works in the r_11167555 department, and was born in Naira.
# 	52 works in the r_2000499664 department, and was born in Naira.
# 	51 works in the r_10644822 department, and was born in Naira.
# 	50 works in the r_10524701 department, and was born in Naira.
# 	49 works in the r_2000045368 department, and was born in Naira.
# 	48 works in the r_11643855 department, and was born in Naira.
# 	47 works in the r_10035468 department, and was born in Naira.
# 	46 works in the r_11312330 department, and was born in Naira.
# 	45 works in the r_11350410 department, and was born in Naira.
# 	44 works in the r_2001571494 department, and was born in Naira.
# 	43 works in the r_10115817 department, and was born in Naira.
# 	42 works in the r_10511402 department, and was born in Naira.
# 	41 works in the r_2000024332 department, and was born in Naira.
# 	40 works in the r_11350136 department, and was born in Naira.
# 	39 works in the r_11062411 department, and was born in Naira.
# 	34 works in the r_2000711610 department, and was born in Naira.
# 	33 works in the r_2002167978 department, and was born in Naira.
# 	32 works in the r_11590432 department, and was born in Naira.
# 	31 works in the r_10989388 department, and was born in Naira.
# 	30 works in the r_2001885358 department, and was born in Naira.
# 	29 works in the r_10967136 department, and was born in Naira.
# 	28 works in the r_2001805795 department, and was born in Naira.
# 	27 works in the r_10346894 department, and was born in Naira.
# 	26 works in the r_10621549 department, and was born in Naira.
# 	25 works in the r_2001851868 department, and was born in Naira.
# 	24 works in the r_10045822 department, and was born in Naira.
# 	23 works in the r_2001950732 department, and was born in Naira.
# 	22 works in the r_11416807 department, and was born in Naira.
# 	21 works in the r_11070654 department, and was born in Naira.
# 	20 works in the r_2000697309 department, and was born in Naira.
# 	19 works in the r_10964329 department, and was born in Naira.
# 	18 works in the r_10325812 department, and was born in Naira.
# 	17 works in the r_11150072 department, and was born in Naira.
# 	16 works in the r_11579860 department, and was born in Naira.
# 	15 works in the r_11336470 department, and was born in Naira.
# 	14 works in the r_2000103392 department, and was born in Naira.
# 	13 works in the r_10391608 department, and was born in Naira.
# 	12 works in the r_2000290080 department, and was born in Naira.
# 	11 works in the r_2002169089 department, and was born in Naira.
# 	10 works in the r_2000534933 department, and was born in Naira.
# 	9 works in the r_2001766295 department, and was born in Naira.
# 	8 works in the r_11673105 department, and was born in Naira.
# 	7 works in the r_2000324828 department, and was born in Naira.
# 	6 works in the r_2000494994 department, and was born in Naira.
# 	5 works in the r_2001046280 department, and was born in Naira.
# 	4 works in the r_11062411 department, and was born in Naira.
# 	3 works in the r_2000302399 department, and was born in Naira.
# 	2 works in the r_11062411 department, and was born in Naira.
# 	1 works in the r_11083734 department, and was born in NGN.
# Processed 8904 lines.
